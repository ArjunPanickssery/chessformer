# %%
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
import numpy as np

from mateenv import MateEnv

env = MateEnv()

model = DQN("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Users/dyusha/research/chess-rl/venv/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
from stable_baselines3.common.base_class import BaseAlgorithm


def evaluate(
    model: BaseAlgorithm,
    num_episodes: int = 100,
    deterministic: bool = True,
) -> float:
    """
    Evaluate an RL agent for `num_episodes`.

    :param model: the RL Agent
    :param env: the gym Environment
    :param num_episodes: number of episodes to evaluate it
    :param deterministic: Whether to use deterministic or stochastic actions
    :return: Mean reward for the last `num_episodes`
    """
    # This function will only work for a single environment
    vec_env = model.get_env()
    obs = vec_env.reset()
    all_episode_rewards = []
    for _ in range(num_episodes):
        episode_rewards = []
        done = False
        # Note: SB3 VecEnv resets automatically:
        # https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api
        # obs = vec_env.reset()
        while not done:
            # _states are only useful when using LSTM policies
            # `deterministic` is to use deterministic actions
            action, _states = model.predict(obs, deterministic=deterministic)
            # here, action, rewards and dones are arrays
            # because we are using vectorized env
            obs, reward, done, _info = vec_env.step(action)
            episode_rewards.append(reward)

        all_episode_rewards.append(sum(episode_rewards))

    mean_episode_reward = np.mean(all_episode_rewards)
    print(f"Mean reward: {mean_episode_reward:.2f} - Num episodes: {num_episodes}")

    return mean_episode_reward

# %%
# Random Agent, before training
mean_reward_before_train = evaluate(model, num_episodes=100, deterministic=True)
# Out:
# Mean reward: -1.99 - Num episodes: 100

# %%
# Train the agent for 10000 steps
model.learn(total_timesteps=10_000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1886     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2136     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2312     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2483     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2240     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2259     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2337     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 28       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2440     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 32       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2473     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2537     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2592     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2626     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2690     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2738     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2813     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 60       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2873     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2916     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2955     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3007     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3023     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 80       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3010     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 84       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3038     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3064     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3070     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3094     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3126     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3133     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 108      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 3141     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3179     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 116      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3196     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3189     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 3156     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 3159     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 132      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3176     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 3174     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 144      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 3187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3204     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 152      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3207     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3225     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 160      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3217     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 164      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3198     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3198     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3212     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3212     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 180      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3216     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3223     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3240     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3190     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3180     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 204      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3189     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 212      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3178     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 216      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3177     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 220      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3189     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 224      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 228      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3197     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 232      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3188     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3173     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 240      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3159     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 244      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3166     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 248      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3160     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 252      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3149     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3151     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3161     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 264      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3164     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3170     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 272      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3167     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3170     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 280      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3166     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 284      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3167     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 288      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3161     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 292      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3167     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3173     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3179     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 304      |
# ----------------------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Train the agent for 10000 steps
# ----> 2 model.learn(total_timesteps=10_000)
#
# File ~/research/chess-rl/venv/lib/python3.11/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~/research/chess-rl/venv/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/research/chess-rl/venv/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/research/chess-rl/venv/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/research/chess-rl/venv/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/research/chess-rl/venv/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/research/chess-rl/venv/lib/python3.11/site-packages/shimmy/openai_gym_compatibility.py:251, in GymV21CompatibilityV0.step(self, action)
#     242 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     243     """Steps through the environment.
#     244
#     245     Args:
#    (...)
#     249         (observation, reward, terminated, truncated, info)
#     250     """
# --> 251     obs, reward, done, info = self.gym_env.step(action)
#     253     if self.render_mode is not None:
#     254         self.render()
#
# File ~/research/chess-rl/mateenv.py:84, in MateEnv.step(self, action)
#      81 real_distance = rook_action % 7 + 1
#      82 rook_move_vector = (real_direction[0] * real_distance, real_direction[1] * real_distance)
# ---> 84 new_rook_position = (current_white_rook_location[0][0] + rook_move_vector[0],
#      85                      current_white_rook_location[1][0] + rook_move_vector[1])
#      87 new_board = self.board.copy()
#      89 legal_move = True
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
